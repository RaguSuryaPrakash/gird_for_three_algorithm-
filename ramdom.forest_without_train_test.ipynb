# %%
import numpy as np
import matplotlib as pyplot
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
param_grid ={'criterion':['mse','mae'],'max_features': ['auto','sqrt','log2'],'n_estimators':[10,100]} 
grid=GridSearchCV(RandomForestRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)

# %%
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# C:\Users\ragus\HOPES\ANACONDA 3\lib\site-packages\sklearn\model_selection\_search.py:926: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\ragus\HOPES\ANACONDA 3\lib\site-packages\sklearn\ensemble\_forest.py:407: FutureWarning: Criterion 'mae' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='absolute_error'` which is equivalent.
#   FutureWarning,
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['mse', 'mae'],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
re= Grid.cv_results_
print=("Best_parameters{}:".format(Grid.best_params_))

# %%
print
# Out:
# "Best_parameters{'criterion': 'mae', 'max_features': 'sqrt', 'n_estimators': 100}:"

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.277318      0.080407         0.007661        0.004455
# 1        2.570422      0.317052         0.108220        0.017239
# 2        0.353050      0.147407         0.052381        0.055250
# 3        2.016297      0.436252         0.147335        0.014941
# 4        0.605043      0.326077         0.055685        0.039346
# 5        1.687625      0.315058         0.108701        0.011540
# 6        2.069409      0.566781         0.044431        0.036063
# 7       21.732994      2.523155         0.088634        0.032152
# 8        1.625284      0.363494         0.028521        0.024989
# 9       14.192362      2.157787         0.156755        0.073964
# 10       2.046407      0.185650         0.089735        0.061349
# 11      10.616847      3.308472         0.062246        0.031400
#
#    param_criterion param_max_features param_n_estimators  \
# 0              mse               auto                 10
# 1              mse               auto                100
# 2              mse               sqrt                 10
# 3              mse               sqrt                100
# 4              mse               log2                 10
# 5              mse               log2                100
# 6              mae               auto                 10
# 7              mae               auto                100
# 8              mae               sqrt                 10
# 9              mae               sqrt                100
# 10             mae               log2                 10
# 11             mae               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'mse', 'max_features': 'auto', '...           0.845162
# 1   {'criterion': 'mse', 'max_features': 'auto', '...           0.849782
# 2   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.841881
# 3   {'criterion': 'mse', 'max_features': 'sqrt', '...           0.857150
# 4   {'criterion': 'mse', 'max_features': 'log2', '...           0.855397
# 5   {'criterion': 'mse', 'max_features': 'log2', '...           0.857280
# 6   {'criterion': 'mae', 'max_features': 'auto', '...           0.830590
# 7   {'criterion': 'mae', 'max_features': 'auto', '...           0.842492
# 8   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.844917
# 9   {'criterion': 'mae', 'max_features': 'sqrt', '...           0.855447
# 10  {'criterion': 'mae', 'max_features': 'log2', '...           0.846894
# 11  {'criterion': 'mae', 'max_features': 'log2', '...           0.857693
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.766360           0.831897           0.807068
# 1            0.767687           0.855058           0.816304
# 2            0.759677           0.838132           0.821033
# 3            0.775023           0.863222           0.829166
# 4            0.767404           0.843174           0.806712
# 5            0.772592           0.858409           0.829478
# 6            0.752299           0.863804           0.807778
# 7            0.764241           0.853760           0.824729
# 8            0.738516           0.832731           0.806994
# 9            0.779312           0.858656           0.828516
# 10           0.765582           0.837211           0.815659
# 11           0.780023           0.853255           0.826749
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.817641         0.813626        0.026913               11
# 1            0.834831         0.824732        0.031541                5
# 2            0.820123         0.816169        0.029577               10
# 3            0.839904         0.832893        0.031370                2
# 4            0.815457         0.817629        0.030742                8
# 5            0.840654         0.831683        0.031454                4
# 6            0.835011         0.817896        0.037328                7
# 7            0.836201         0.824285        0.031457                6
# 8            0.831423         0.810916        0.038235               12
# 9            0.845581         0.833502        0.029057                1
# 10           0.816863         0.816442        0.028094                9
# 11           0.842350         0.832014        0.028100                3

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age:1
# BMI:35
# Children:4
# Sex Male 0 or 1:2
# Smoker Yes 0 or 1:1

# %%
Future_Prediction=Grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print=("Future_Prediction{}".format(Future_Prediction))
# Out:
# C:\Users\ragus\HOPES\ANACONDA 3\lib\site-packages\sklearn\base.py:451: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print
# Out:
# 'Future_Prediction[34999.10425615]'
